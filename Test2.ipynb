# %%
from pymatgen.core.structure import Structure
from pymatgen.symmetry.analyzer import SpacegroupAnalyzer
from aflow import *
from RDF import *

def convert(struc):
    
    composition = []
    atom_type = []
    dict = struc.composition.as_dict()
    
    for ele in struc.composition.elements:
        composition.append(int(dict[ele.name]))
        atom_type.append(ele.name)
        
    crystal0 = crystal(fileformat='poscar',
        lattice = struc.lattice.matrix,
        atom_type = atom_type,
        composition = composition,
        coordinate = struc.frac_coords)
    
    return crystal0

# %%
struc = Structure.from_file("POSCAR-NaCl")
rdf = RDF(convert(struc))
#print(rdf)
#print(rdf1)
rdf.plot_RDF()
# Out:
# C:\Users\vinit\Anaconda3\lib\site-packages\pymatgen\io\cif.py:43: UserWarning: Please install optional dependency pybtex if youwant to extract references from CIF files.
#   warnings.warn("Please install optional dependency pybtex if you"

# %%
struc.make_supercell([2, 2, 2])

# %%
rdf2 = RDF(convert(struc))
#print(rdf)
rdf2.plot_RDF()
