# %%
from aflow import *
from RDF import *

# %%
Listruc = Structure.from_file("POSCAR-LiCl")
rdfLi = RDF(Listruc)
rdfLi.plot_RDF()

# %%
Nastruc = Structure.from_file("POSCAR-NaCl")
rdfNa = RDF(Nastruc)
rdfNa.plot_RDF()

# %%
Kstruc = Structure.from_file("POSCAR-KCl")
rdfK = RDF(Kstruc)
rdfK.plot_RDF()

# %% [markdown]
# The PDF of KCl and LiCl are in agreement with each other since the K atom is larger than Li atom. Therefore, we would expect the a shorter bond for Li.
